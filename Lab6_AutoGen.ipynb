# %% [markdown]
# <a href="https://colab.research.google.com/github/Nageshngu/Agentic-AI-Lab/blob/main/Lab6_AutoGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y autogen pyautogen
# !pip install pyautogen==0.2.35
# Out:
# WARNING: Skipping autogen as it is not installed.
# Found existing installation: pyautogen 0.2.35
# Uninstalling pyautogen-0.2.35:
#   Successfully uninstalled pyautogen-0.2.35
# Collecting pyautogen==0.2.35
#   Using cached pyautogen-0.2.35-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: diskcache in /usr/local/lib/python3.12/dist-packages (from pyautogen==0.2.35) (5.6.3)
# Requirement already satisfied: docker in /usr/local/lib/python3.12/dist-packages (from pyautogen==0.2.35) (7.2.0)
# Requirement already satisfied: flaml in /usr/local/lib/python3.12/dist-packages (from pyautogen==0.2.35) (2.6.0)
# Requirement already satisfied: numpy<2,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from pyautogen==0.2.35) (1.26.4)
# Requirement already satisfied: openai>=1.3 in /usr/local/lib/python3.12/dist-packages (from pyautogen==0.2.35) (2.45.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from pyautogen==0.2.35) (26.2)
# Requirement already satisfied: pydantic!=2.6.0,<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from pyautogen==0.2.35) (2.13.4)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from pyautogen==0.2.35) (1.2.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from pyautogen==0.2.35) (3.3.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from pyautogen==0.2.35) (0.13.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.3->pyautogen==0.2.35) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.3->pyautogen==0.2.35) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.3->pyautogen==0.2.35) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.3->pyautogen==0.2.35) (0.16.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.3->pyautogen==0.2.35) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=1.3->pyautogen==0.2.35) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from openai>=1.3->pyautogen==0.2.35) (4.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.6.0,<3,>=1.10->pyautogen==0.2.35) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.6.0,<3,>=1.10->pyautogen==0.2.35) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.6.0,<3,>=1.10->pyautogen==0.2.35) (0.4.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from docker->pyautogen==0.2.35) (2.32.4)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from docker->pyautogen==0.2.35) (2.5.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken->pyautogen==0.2.35) (2025.11.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai>=1.3->pyautogen==0.2.35) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.3->pyautogen==0.2.35) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.3->pyautogen==0.2.35) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.3->pyautogen==0.2.35) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->docker->pyautogen==0.2.35) (3.4.9)
# Using cached pyautogen-0.2.35-py3-none-any.whl (318 kB)
# Installing collected packages: pyautogen
# Successfully installed pyautogen-0.2.35

# %%
config_list = [{

    'model': 'llama-3.1-8b-instant',

    'api_key': "PASTE_YOUR_GROQ_API_KEY_HERE",

    'base_url': 'https://api.groq.com/openai/v1'

}]

llm_config = {'config_list': config_list, 'temperature': 0.4}

# %%
import autogen


writer = autogen.AssistantAgent(

    name='Writer',

    system_message='You write short, clear blog posts. '

                   'When given feedback, rewrite to improve it.',

    llm_config=llm_config)



critic = autogen.AssistantAgent(

    name='Critic',

    system_message='You review blog posts and give 2-3 specific '

                   'improvements. If it is good, reply APPROVED.',

    llm_config=llm_config)
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
critic.initiate_chat(

    writer,

    message='Write a 150-word blog post about the benefits of reading.',

    max_turns=4)
# Out:
# Critic (to Writer):
#
# Write a 150-word blog post about the benefits of reading.
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 07-17 04:45:48] {329} WARNING - Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# WARNING:autogen.oai.client:Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# Writer (to Critic):
#
# **The Power of Reading: Unlocking a World of Benefits**
#
# Reading is a timeless activity that offers numerous benefits for individuals of all ages. Not only does it improve our vocabulary and communication skills, but it also enhances our critical thinking and analytical abilities. By immersing ourselves in different genres and authors, we gain a deeper understanding of the world and its complexities.
#
# Reading can also be a great stress-reliever, allowing us to escape into a different reality and forget about our daily worries. Moreover, it can broaden our perspectives, challenge our assumptions, and foster empathy and compassion. Whether it's a novel, a memoir, or a self-help book, reading has the power to transform our lives and open our minds to new ideas and experiences. So, grab a book and get reading – your mind and body will thank you!
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 07-17 04:45:48] {329} WARNING - Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# WARNING:autogen.oai.client:Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# Critic (to Writer):
#
# Here are 2-3 specific improvements for the blog post:
#
# 1. **Add a clear thesis statement**: While the post highlights several benefits of reading, it would be more effective to start with a clear thesis statement that sets the tone for the rest of the article. For example, "Reading is a powerful tool that can transform our lives in countless ways, from improving our communication skills to broadening our perspectives and fostering empathy."
#
# 2. **Use more specific examples**: While the post mentions the benefits of reading, it would be more engaging to use specific examples or anecdotes to illustrate these points. For example, "Reading a memoir about a person's struggle with mental health can foster empathy and compassion, while reading a self-help book can challenge our assumptions and inspire us to make positive changes in our lives."
#
# 3. **Consider a more compelling conclusion**: The final sentence, "So, grab a book and get reading – your mind and body will thank you!" is a bit generic and doesn't leave a lasting impression on the reader. Consider ending with a more thought-provoking question or a call to action that encourages readers to take action.
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 07-17 04:45:49] {329} WARNING - Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# WARNING:autogen.oai.client:Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# Writer (to Critic):
#
# **The Power of Reading: Unlocking a World of Benefits**
#
# Reading is a powerful tool that can transform our lives in countless ways, from improving our communication skills to broadening our perspectives and fostering empathy. Whether we're devouring a novel, exploring a new genre, or learning from a self-help book, reading has the ability to shape our thoughts, behaviors, and relationships.
#
# One of the most significant benefits of reading is its ability to improve our communication skills. By immersing ourselves in different writing styles and genres, we can develop a more nuanced understanding of language and its power to convey complex ideas and emotions. For example, reading a collection of poetry can help us appreciate the beauty of language and its ability to evoke emotions, while reading a memoir about a person's struggle with mental health can foster empathy and compassion.
#
# Reading can also be a great stress-reliever, allowing us to escape into a different reality and forget about our daily worries. Moreover, it can challenge our assumptions, inspire us to make positive changes in our lives, and broaden our perspectives on the world. So, what will you read next? Will it be a classic novel that challenges your worldview, a self-help book that inspires you to take action, or a memoir that sparks a new passion? Whatever it is, remember that reading has the power to transform your life in profound and lasting ways.
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 07-17 04:45:49] {329} WARNING - Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# WARNING:autogen.oai.client:Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# Critic (to Writer):
#
# APPROVED
#
# The revised blog post has made significant improvements:
#
# 1. **Clear thesis statement**: The post now starts with a clear and concise thesis statement that sets the tone for the rest of the article.
# 2. **Specific examples**: The post provides specific examples to illustrate the benefits of reading, such as reading poetry to appreciate language and reading a memoir to foster empathy.
# 3. **Compelling conclusion**: The final sentence is more thought-provoking and encourages readers to take action, leaving a lasting impression on the reader.
#
# Overall, the post is well-structured, engaging, and effectively conveys the benefits of reading.
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 07-17 04:45:50] {329} WARNING - Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# WARNING:autogen.oai.client:Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# Writer (to Critic):
#
# I'm glad to hear that the revised blog post meets your expectations. I'll keep working to improve my writing skills and provide high-quality content. If you have any other feedback or requests, feel free to share them.
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 07-17 04:45:50] {329} WARNING - Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# WARNING:autogen.oai.client:Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# Critic (to Writer):
#
# I'm glad to see you're committed to continuous improvement. Here are a few additional suggestions to help you refine your writing skills:
#
# 1. **Use active voice**: While your writing is clear and concise, some sentences are written in passive voice. Try to rephrase them in active voice to make your writing more engaging and dynamic.
# 2. **Vary sentence structure**: Your writing is mostly composed of simple sentences. Consider mixing in some compound or complex sentences to create more interest and variety.
# 3. **Use sensory details**: To make your writing more vivid and engaging, try to incorporate sensory details that appeal to the reader's senses. For example, instead of saying "reading can be a great stress-reliever," you could say "the feel of turning pages, the smell of fresh paper, and the sound of turning pages can transport you to a different world, calming your mind and soothing your soul."
#
# These are just a few suggestions to help you refine your writing skills. Keep up the good work, and I'm happy to provide feedback and guidance whenever you need it!
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 07-17 04:45:52] {329} WARNING - Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# WARNING:autogen.oai.client:Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# Writer (to Critic):
#
# Thank you for the additional feedback and suggestions. I'll work on implementing them to improve my writing skills.
#
# **Using active voice**: I'll make a conscious effort to rephrase passive voice sentences in active voice. For example, instead of saying "Reading a memoir about a person's struggle with mental health can foster empathy and compassion," I could say "Reading a memoir about a person's struggle with mental health can help you develop empathy and compassion."
#
# **Varying sentence structure**: I'll mix in compound and complex sentences to create more interest and variety. For example, instead of saying "Reading can improve our communication skills and broaden our perspectives," I could say "Reading can improve our communication skills by exposing us to different writing styles and broaden our perspectives by introducing us to new ideas and cultures."
#
# **Using sensory details**: I'll try to incorporate sensory details to make my writing more vivid and engaging. For example, instead of saying "Reading can be a great stress-reliever," I could say "The feel of turning pages, the smell of fresh paper, and the sound of turning pages can transport you to a different world, calming your mind and soothing your soul."
#
# Here's an updated version of the blog post incorporating these suggestions:
#
# **The Power of Reading: Unlocking a World of Benefits**
#
# Reading is a powerful tool that can transform our lives in countless ways, from improving our communication skills to broadening our perspectives and fostering empathy. Whether we're devouring a novel, exploring a new genre, or learning from a self-help book, reading has the ability to shape our thoughts, behaviors, and relationships.
#
# As we turn the pages of a book, the feel of the paper, the sound of the words, and the scent of the ink can transport us to a different world, calming our minds and soothing our souls. Reading can improve our communication skills by exposing us to different writing styles and broaden our perspectives by introducing us to new ideas and cultures. For example, reading a collection of poetry can help us appreciate the beauty of language and its ability to evoke emotions, while reading a memoir about a person's struggle with mental health can help us develop empathy and compassion.
#
# Reading can also be a great stress-reliever, allowing us to escape into a different reality and forget about our daily worries. As we lose ourselves in a good book, our minds become clearer, our thoughts more focused, and our hearts more at peace. So, what will you read next? Will it be a classic novel that challenges your worldview, a self-help book that inspires you to take action, or a memoir that sparks a new passion? Whatever it is, remember that reading has the power to transform your life in profound and lasting ways.
#
# --------------------------------------------------------------------------------
# ChatResult(chat_id=None, chat_history=[{'content': 'Write a 150-word blog post about the benefits of reading.', 'role': 'assistant', 'name': 'Critic'}, {'content': "**The Power of Reading: Unlocking a World of Benefits**\n\nReading is a timeless activity that offers numerous benefits for individuals of all ages. Not only does it improve our vocabulary and communication skills, but it also enhances our critical thinking and analytical abilities. By immersing ourselves in different genres and authors, we gain a deeper understanding of the world and its complexities.\n\nReading can also be a great stress-reliever, allowing us to escape into a different reality and forget about our daily worries. Moreover, it can broaden our perspectives, challenge our assumptions, and foster empathy and compassion. Whether it's a novel, a memoir, or a self-help book, reading has the power to transform our lives and open our minds to new ideas and experiences. So, grab a book and get reading – your mind and body will thank you!", 'role': 'user', 'name': 'Writer'}, {'content': 'Here are 2-3 specific improvements for the blog post:\n\n1. **Add a clear thesis statement**: While the post highlights several benefits of reading, it would be more effective to start with a clear thesis statement that sets the tone for the rest of the article. For example, "Reading is a powerful tool that can transform our lives in countless ways, from improving our communication skills to broadening our perspectives and fostering empathy."\n\n2. **Use more specific examples**: While the post mentions the benefits of reading, it would be more engaging to use specific examples or anecdotes to illustrate these points. For example, "Reading a memoir about a person\'s struggle with mental health can foster empathy and compassion, while reading a self-help book can challenge our assumptions and inspire us to make positive changes in our lives."\n\n3. **Consider a more compelling conclusion**: The final sentence, "So, grab a book and get reading – your mind and body will thank you!" is a bit generic and doesn\'t leave a lasting impression on the reader. Consider ending with a more thought-provoking question or a call to action that encourages readers to take action.', 'role': 'assistant', 'name': 'Critic'}, {'content': "**The Power of Reading: Unlocking a World of Benefits**\n\nReading is a powerful tool that can transform our lives in countless ways, from improving our communication skills to broadening our perspectives and fostering empathy. Whether we're devouring a novel, exploring a new genre, or learning from a self-help book, reading has the ability to shape our thoughts, behaviors, and relationships.\n\nOne of the most significant benefits of reading is its ability to improve our communication skills. By immersing ourselves in different writing styles and genres, we can develop a more nuanced understanding of language and its power to convey complex ideas and emotions. For example, reading a collection of poetry can help us appreciate the beauty of language and its ability to evoke emotions, while reading a memoir about a person's struggle with mental health can foster empathy and compassion.\n\nReading can also be a great stress-reliever, allowing us to escape into a different reality and forget about our daily worries. Moreover, it can challenge our assumptions, inspire us to make positive changes in our lives, and broaden our perspectives on the world. So, what will you read next? Will it be a classic novel that challenges your worldview, a self-help book that inspires you to take action, or a memoir that sparks a new passion? Whatever it is, remember that reading has the power to transform your life in profound and lasting ways.", 'role': 'user', 'name': 'Writer'}, {'content': 'APPROVED\n\nThe revised blog post has made significant improvements:\n\n1. **Clear thesis statement**: The post now starts with a clear and concise thesis statement that sets the tone for the  ...
