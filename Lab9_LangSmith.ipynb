# %% [markdown]
# <a href="https://colab.research.google.com/github/Nageshngu/Agentic-AI-Lab/blob/main/Lab9_LangSmith.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-groq langsmith -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 2.5 MB/s eta 0:00:00

# %%
import os

os.environ['LANGCHAIN_TRACING_V2'] = 'true'

os.environ['LANGCHAIN_API_KEY'] = "PASTE_YOUR_LANGCHAIN_API_KEY_HERE"

os.environ['LANGCHAIN_PROJECT'] = 'Lab9-Agentic-AI'

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(api_key="PASTE_YOUR_GROQ_API_KEY_HERE",

               model="llama-3.1-8b-instant", temperature=0)



question = ('A shop sells pens at 12 rupees each. '

            'If I buy 7 and pay with 100, how much change? '

            'Think step by step.')

print(llm.invoke(question).content)
# Out:
# To find the change, let's break down the problem step by step:
#
# 1. The cost of one pen is 12 rupees.
# 2. You are buying 7 pens, so the total cost will be 7 * 12 = 84 rupees.
# 3. You are paying with 100 rupees.
# 4. To find the change, subtract the total cost from the amount you paid: 100 - 84 = 16 rupees.
#
# So, your change will be 16 rupees.
